# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans,AgglomerativeClustering,DBSCAN,SpectralClustering
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn import tree
from sklearn import metrics

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading the dataset

# %%
df = pd.read_csv("Customer Data.csv")
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %% [markdown]
# # EDA

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
# filling mean value in place of missing values in the dataset
df["MINIMUM_PAYMENTS"] = df["MINIMUM_PAYMENTS"].fillna(df["MINIMUM_PAYMENTS"].mean())
df["CREDIT_LIMIT"] = df["CREDIT_LIMIT"].fillna(df["CREDIT_LIMIT"].mean())

# %%
df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
# checking for duplicate rows in the dataset
df.duplicated().sum()
# Out:
# 0

# %%
# drop CUST_ID column because it is not used
df.drop(columns=["CUST_ID"],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE'],
#       dtype='object')

# %%
plt.figure(figsize=(30,45))
for i, col in enumerate(df.columns):
    if df[col].dtype != 'object':
        ax = plt.subplot(9, 2, i+1)
        sns.kdeplot(df[col], ax=ax)
        plt.xlabel(col)
        
plt.show()

# %%
plt.figure(figsize=(10,60))
for i in range(0,17):
    plt.subplot(17,1,i+1)
    sns.distplot(df[df.columns[i]],kde_kws={'color':'b','bw': 0.1,'lw':3,'label':'KDE'},hist_kws={'color':'g'})
    plt.title(df.columns[i])
plt.tight_layout()

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# # Scaling the DataFrame

# %%
scaled_df = scalar.fit_transform(df)

# %% [markdown]
# # Dimensionality reduction
# Converting the DataFrame into 2D DataFrame for visualization

# %%
pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_df)
pca_df = pd.DataFrame(data=principal_components ,columns=["PCA1","PCA2"])
pca_df
# Out:
#           PCA1      PCA2
# 0    -1.682216 -1.076443
# 1    -1.138299  2.506452
# 2     0.969666 -0.383575
# 3    -0.873608  0.043221
# 4    -1.599435 -0.688588
# ...        ...       ...
# 8945 -0.359620 -2.016119
# 8946 -0.564347 -1.639055
# 8947 -0.926193 -1.810754
# 8948 -2.336548 -0.657952
# 8949 -0.556443 -0.400517
#
# [8950 rows x 2 columns]

# %% [markdown]
# # Hyperparameter tuning
# ## Finding 'k' value by Elbow Method

# %%
inertia = []
range_val = range(1,15)
for i in range_val:
    kmean = KMeans(n_clusters=i)
    kmean.fit_predict(pd.DataFrame(scaled_df))
    inertia.append(kmean.inertia_)
plt.plot(range_val,inertia,'bx-')
plt.xlabel('Values of K') 
plt.ylabel('Inertia') 
plt.title('The Elbow Method using Inertia') 
plt.show()

# %% [markdown]
# # Model Building using KMeans

# %%
kmeans_model=KMeans(4)
kmeans_model.fit_predict(scaled_df)
pca_df_kmeans= pd.concat([pca_df,pd.DataFrame({'cluster':kmeans_model.labels_})],axis=1)

# %% [markdown]
# # Visualizing the clustered dataframe

# %%
plt.figure(figsize=(8,8))
ax=sns.scatterplot(x="PCA1",y="PCA2",hue="cluster",data=pca_df_kmeans,palette=['red','green','blue','black'])
plt.title("Clustering using K-Means Algorithm")
plt.show()

# %%
# find all cluster centers
cluster_centers = pd.DataFrame(data=kmeans_model.cluster_centers_,columns=[df.columns])
# inverse transform the data
cluster_centers = scalar.inverse_transform(cluster_centers)
cluster_centers = pd.DataFrame(data=cluster_centers,columns=[df.columns])
cluster_centers
# Out:
#        BALANCE BALANCE_FREQUENCY    PURCHASES ONEOFF_PURCHASES  \
# 0   894.907458          0.934734  1236.178934       593.974874
# 1  1011.751528          0.789871   269.973466       209.853863
# 2  4602.462714          0.968415   501.896219       320.373681
# 3  3551.153761          0.986879  7681.620098      5095.878826
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0             642.478274   210.570626            0.885165
# 1              60.386625   595.759339            0.170146
# 2             181.607404  4520.724309            0.287731
# 3            2587.208264   653.638891            0.946418
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   0.297070                         0.711842
# 1                   0.086281                         0.080578
# 2                   0.138934                         0.185516
# 3                   0.739031                         0.788060
#
# ...

# %%
# Creating a target column "Cluster" for storing the cluster segment
cluster_df = pd.concat([df,pd.DataFrame({'Cluster':kmeans_model.labels_})],axis=1)
cluster_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
cluster_1_df = cluster_df[cluster_df["Cluster"]==0]
cluster_1_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 2     2495.148862           1.000000     773.17            773.17
# 5     1809.828751           1.000000    1333.28              0.00
# 7     1823.652743           1.000000     436.20              0.00
# 10    1293.124939           1.000000     920.12              0.00
# 12    1516.928620           1.000000    3217.99           2500.23
# ...           ...                ...        ...               ...
# 8940   130.838554           1.000000     591.24              0.00
# 8942    40.829749           1.000000     113.28              0.00
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 2                       0.00           0.0             1.000000
# ...

# %%
cluster_2_df = cluster_df[cluster_df["Cluster"]==1]
cluster_2_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# 8     1014.926473           1.000000     861.49            661.49
# 9      152.225975           0.545455    1281.60           1281.60
# ...           ...                ...        ...               ...
# 8939   728.352548           1.000000     734.40            734.40
# 8943     5.871712           0.500000      20.90             20.90
# 8944   193.571722           0.833333    1012.73           1012.73
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                       95.4      0.000000             0.166667
# ...

# %%
cluster_3_df = cluster_df[cluster_df["Cluster"]==2]
cluster_3_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 1     3202.467416           0.909091       0.00              0.00
# 15    6886.213231           1.000000    1611.70              0.00
# 23    3800.151377           0.818182    4248.35           3454.56
# 24    5368.571219           1.000000       0.00              0.00
# 28    7152.864372           1.000000     387.05            204.55
# ...           ...                ...        ...               ...
# 8857  2330.222764           1.000000    1320.00              0.00
# 8858   812.934042           1.000000      50.00             50.00
# 8869  2171.222526           1.000000     791.18            791.18
# 8915   381.341657           1.000000      78.00              0.00
# 8941  5967.475270           0.833333     214.55              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 1                       0.00   6442.945483             0.000000
# ...

# %%
cluster_4_df = cluster_df[cluster_df["Cluster"] == 3]
cluster_4_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 6      627.260806           1.000000    7091.01           6402.63
# 21    6369.531318           1.000000    6359.95           5910.04
# 57    2386.330629           1.000000    5217.62           4789.09
# 84    1935.362486           1.000000    4915.60           4515.34
# 90    9381.255094           1.000000    5100.07           1147.83
# ...           ...                ...        ...               ...
# 8215  4436.557694           1.000000    6005.90           5838.38
# 8541  3326.323283           1.000000    8209.77           2218.28
# 8662   599.909949           1.000000    4947.32           3149.59
# 8689   368.318662           0.909091    8053.95           8053.95
# 8737  2533.618119           0.909091    5633.83           2985.92
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 6                     688.38      0.000000             1.000000
# ...

# %%
#Visualization
sns.countplot(x='Cluster', data=cluster_df)
# Out:
# <AxesSubplot:xlabel='Cluster', ylabel='count'>

# %%
for c in cluster_df.drop(['Cluster'],axis=1):
    grid= sns.FacetGrid(cluster_df, col='Cluster')
    grid= grid.map(plt.hist, c)
plt.show()

# %% [markdown]
# # Saving the kmeans clustering model and the data with cluster label

# %%
#Saving Scikitlearn models
import joblib
joblib.dump(kmeans_model, "kmeans_model.pkl")
# Out:
# ['kmeans_model.pkl']

# %%
cluster_df.to_csv("Clustered_Customer_Data.csv")

# %% [markdown]
# # Training and Testing the model accuracy using decision tree

# %%
#Split Dataset
X = cluster_df.drop(['Cluster'],axis=1)
y= cluster_df[['Cluster']]
X_train, X_test, y_train, y_test =train_test_split(X, y, test_size=0.3)

# %%
X_train
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 6651  3347.229846           1.000000     480.00               0.0
# 7355   745.368581           1.000000     153.89               0.0
# 8143  1179.613243           1.000000       0.00               0.0
# 106    408.656365           1.000000     941.64               0.0
# 8801   275.020950           1.000000    1943.00            1943.0
# ...           ...                ...        ...               ...
# 6574    56.681680           1.000000     827.20               0.0
# 8306  2128.836017           1.000000       0.00               0.0
# 8416     9.712731           0.636364     128.94               0.0
# 6418  1248.332959           1.000000     478.32             198.0
# 8623    70.954998           0.818182     616.67               0.0
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 6651                  480.00   1760.145824             0.833333
# ...

# %%
X_test
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 2979  3586.660250           1.000000     342.00            177.00
# 3657  1390.597054           1.000000     724.40            724.40
# 7550  2513.983606           1.000000       0.00              0.00
# 5655  1593.655423           1.000000     358.70            111.30
# 4281     2.872146           0.181818      37.00             37.00
# ...           ...                ...        ...               ...
# 3032  5606.778018           1.000000     283.88            124.88
# 2319   900.482738           1.000000       0.00              0.00
# 5318   303.054817           0.636364     894.40            609.40
# 6344  1527.826042           1.000000    3191.00           3191.00
# 4431   508.598624           1.000000       0.00              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 2979                   165.0   5409.095889             0.333333
# ...

# %%
#Decision_Tree
model= DecisionTreeClassifier(criterion="entropy")
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
#Confusion_Matrix
print(metrics.confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[ 954   36   19    7]
#  [  37 1154   23    0]
#  [  11   36  298    2]
#  [  10    1    3   94]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      1016
#            1       0.94      0.95      0.95      1214
#            2       0.87      0.86      0.86       347
#            3       0.91      0.87      0.89       108
#
#     accuracy                           0.93      2685
#    macro avg       0.92      0.90      0.91      2685
# weighted avg       0.93      0.93      0.93      2685

# %% [markdown]
# # Saving the Decision tree model for future prediction

# %%
import pickle
filename = 'final_model.sav'
pickle.dump(model, open(filename, 'wb'))
 
# some time later...
 
# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, y_test)
print(result,'% Acuuracy')
# Out:
# 0.931098696461825 % Acuuracy

# %% [markdown]
# AgglomerativeClustering

# %%
import pandas as pd
from sklearn.cluster import AgglomerativeClustering

# %%
#Load the Data 
data = pd.read_csv("C:/Users/priya/OneDrive/Desktop/maybe/MarketSegmentation/Customer Data.csv")

# %%
#Select the features for clustering
features = ['CUST_ID', 'BALANCE', 'PURCHASES', 'CREDIT_LIMIT'] 
features
# Out:
# ['CUST_ID', 'BALANCE', 'PURCHASES', 'CREDIT_LIMIT']

# %%
#Normalize the data 
data_norm = (data[features] - data[features].mean())/data[features].std()

# %%
#set up the clustering model
model = AgglomerativeClustering(n_clusters=4, linkage = 'ward')

# %%
# check for missing or invalid values
print(df.isnull().sum())
print(df.isin([np.nan, np.inf, -np.inf]).sum())
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ...

# %%
# handle missing or invalid values
df = df.dropna() # remove rows with missing values
df = df.replace([np.inf, -np.inf], np.nan).dropna() # remove rows with invalid values

# %%
# normalize the data
scaler = StandardScaler()
data_norm = scaler.fit_transform(df)

# %%
# fit the Agglomerative Clustering model and predict the clusters
model = AgglomerativeClustering(n_clusters=3)
clusters = model.fit_predict(data_norm)

# %%
#fit the model and predict the clusters
clusters = model.fit_predict(data_norm)

# %%
# add the cluster labels into the original data
data['cluster']=clusters

# %%
# Print cluster sizes
print(data['cluster'].value_counts())
# Out:
# 1    4668
# 0    3418
# 2     864
# Name: cluster, dtype: int64

# %%
from sklearn.metrics import silhouette_score

# calculate the silhouette score(mox shloud be -1 tp 1)
silhouette_avg = silhouette_score(data_norm, clusters)
print("The average silhouette score is :", silhouette_avg)
# Out:
# The average silhouette score is : 0.1731098007232828

# %% [markdown]
# ### Spectral Clustering

# %%
import pandas as pd
from sklearn.cluster import SpectralClustering
from sklearn.preprocessing import StandardScaler

# %%
# load the data
data = pd.read_csv('C:/Users/priya/OneDrive/Desktop/maybe/MarketSegmentation/Customer Data.csv')

# %%
# drop any rows with missing data
data.dropna(inplace=True)

# %%
# select the relevant features for clustering
X = data[['CUST_ID', 'PURCHASES', 'BALANCE', 'CREDIT_LIMIT']]

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
# Load data
data = pd.read_csv("C:/Users/priya/OneDrive/Desktop/maybe/MarketSegmentation/Customer Data.csv")

# %%
# One-hot encode categorical features
data_encoded = pd.get_dummies(data, columns=['CUST_ID', 'PURCHASES', 'BALANCE', 'CREDIT_LIMIT'])

# %%
# Standardize numeric features
scaler = StandardScaler()
X_norm = scaler.fit_transform(data_encoded)

# %%
import numpy as np

# check for missing values
print(np.isnan(X_norm).any())
# Out:
# True

# %%
# check for infinity
print(np.isinf(X_norm).any())
# Out:
# False

# %%
# fill NaN values with 0
data_encoded.fillna(0, inplace=True)

# %%
# normalize the data
scaler = StandardScaler()
X_norm = scaler.fit_transform(data_encoded)

# %%
#check for missing or invalid values 
print(data.isnull().sum())
print(data.isin([np.nan, np.inf, - np.inf]).sum())
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# ...

# %%
#handling missing or invalid values
df=df.dropna() #remove rows with missing values
df=df.replace([np.inf, -np.inf], np.nan).dropna() #remove rows with invalid values

# %%
# normalize the data
scaler = StandardScaler()
X_norm = scaler.fit_transform(data_encoded)

# %%
# create the spectral clustering model and fit to data
model = SpectralClustering(n_clusters=3, affinity='rbf', gamma=0.1)
model.fit(X_norm)
# Out:
# SpectralClustering(gamma=0.1, n_clusters=3)

# %%
# add cluster labels to data
data['cluster_labels'] = model.labels_

# %%
# view the results
print(data.head())
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
#Accuracy
from sklearn.metrics import silhouette_score

# calculate silhouette score(max range: -1 to 1)
silhouette_avg = silhouette_score(X_norm, model.labels_)

print("The average silhouette_score is :", silhouette_avg)
# Out:
# The average silhouette_score is : -0.0049437833327254585

# %% [markdown]
# ### DBSCAN clustering

# %%
from sklearn.cluster import DBSCAN
import numpy as np

# %%
# create the DBSCAN clustering model
model = DBSCAN(eps=0.5, min_samples=5)

# %%
#fill the Nan values with Zero


data_encoded.fillna(0, inplace=True)

# %%
#normalize the data
scalar= StandardScaler()
X_norm= scalar.fit_transform(data_encoded)

# %%
# check for missing or invalid values
print(data.isnull().sum())
print(data.isin([np.nan, np.inf, -np.inf]).sum())
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# cluster_labels                        0
# dtype: int64
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ...

# %%
#handling missing or invalid values
data=data.dropna() #remove rows with missing values
data= data.replace([np.inf, -np.inf], np.nan).dropna() # remove rows with invalid values
data
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 4     C10005   817.714335           1.000000      16.00             16.00
# 5     C10006  1809.828751           1.000000    1333.28              0.00
# ...      ...          ...                ...        ...               ...
# 8943  C19184     5.871712           0.500000      20.90             20.90
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
# fit the model to the normalized data
model.fit(X_norm)
# Out:
# DBSCAN(eps=0.4)

# %%
# extract the cluster labels
labels = model.labels_
labels
# Out:
# array([-1, -1, -1, ..., -1, -1, -1], dtype=int64)

# %%
# calculate the number of clusters
n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
n_clusters
# Out:
# 0

# %%
# print the number of clusters and the cluster labels
print("Number of clusters:", n_clusters)
print("Cluster labels:", labels)
# Out:
# Number of clusters: 0
# Cluster labels: [-1 -1 -1 ... -1 -1 -1]

# %%
# accuracy 
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# %%
# create DBSCAN clustering model and fit to data
model = DBSCAN(eps=0.5, min_samples=5)
model.fit(X_norm)
# Out:
# DBSCAN()

# %%
score= silhouette_score(data_norm, clusters)

# %%
print('silhouette score:', score )
# Out:
# silhouette score: 0.1731098007232828
